# %%
import numpy as np
import pandas as pd

# %%
test = pd.read_csv('2012_data.csv', index_col=0)
test
# Out:
# c:\Users\trist\AppData\Local\Programs\Python\Python38\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (29,30,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        number  driver_number  lap_number  lap_time  lap_improvement  \
# 0         2.0            0.0         1.0  1:56.219              0.0
# 1         1.0            2.0         1.0  1:57.002              0.0
# 2         3.0            0.0         1.0  1:57.317              0.0
# 3        12.0            1.0         1.0  1:59.921              0.0
# 4        21.0            2.0         1.0  2:00.254              0.0
# ...       ...            ...         ...       ...              ...
# 54427     2.0            0.0       190.0  1:50.812              0.0
# 54428     1.0            1.0       190.0  1:56.416              0.0
# 54429     7.0            0.0       191.0  1:54.136              0.0
# ...
